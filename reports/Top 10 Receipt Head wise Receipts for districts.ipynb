# %% [markdown]
# ### Top 10 Receipt Heads for Districts

# %%
import basic_receipt_analysis_for_receipt_head_date_and_challan_wise_data as analysis_plot

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('BILASPUR')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('CHAMBA')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('HAMIRPUR')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('KANGRA')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('KINNAUR')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('KULLU')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('LAHAUL & SPITI')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('MANDI')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('SHIMLA')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('SIRMAUR')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('SOLAN')

# %%
analysis_plot.plot_top_10_receipt_heads_for_district('UNA')

# %% [markdown]
# License Fee is most occuring major receipt head for all districts except Solan and Lahaul & Spiti.
