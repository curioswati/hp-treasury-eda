# %% [markdown]
# ### Time Series Receipt for different districts

# %%
import basic_receipt_analysis_for_receipt_head_date_and_challan_wise_data as analysis_plot

# %%
analysis_plot.plot_time_series_for_district('BILASPUR')

# %%
analysis_plot.plot_time_series_for_district('CHAMBA')

# %%
analysis_plot.plot_time_series_for_district('HAMIRPUR')

# %%
analysis_plot.plot_time_series_for_district('KANGRA')

# %%
analysis_plot.plot_time_series_for_district('KINNAUR')

# %%
analysis_plot.plot_time_series_for_district('KULLU')

# %%
analysis_plot.plot_time_series_for_district('LAHAUL & SPITI')

# %%
analysis_plot.plot_time_series_for_district('MANDI')

# %%
analysis_plot.plot_time_series_for_district('SHIMLA')

# %%
analysis_plot.plot_time_series_for_district('SIRMAUR')

# %%
analysis_plot.plot_time_series_for_district('SOLAN')

# %%
analysis_plot.plot_time_series_for_district('UNA')

# %% [markdown]
# Except some exceptions, major receipt revenue was made in the beginning of FY2018-2019(i.e. April and May 2018) by all districts.

# %% [markdown]
# Hamirpur seem to be making a uniform pattern as compared to other districts.
