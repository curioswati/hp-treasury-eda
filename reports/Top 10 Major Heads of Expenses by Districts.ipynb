# %% [markdown]
# ### Top 10 Major heads for expenses made by districts.

# %%
import basic_expenditure_analysis_for_ddo_hoa_soe_vc_bill_wise_data as analysis_plot

# %%
analysis_plot.plot_top_10_major_heads_for_district('BILASPUR', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('CHAMBA', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('HAMIRPUR', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('KANGRA', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('KINNAUR', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('KULLU', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('LAHAUL & SPITI', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('MANDI', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('SHIMLA', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('SIRMAUR', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('SOLAN', 'GROSS')

# %%
analysis_plot.plot_top_10_major_heads_for_district('UNA', 'GROSS')

# %% [markdown]
# As we can see, "General Education" has the most money spent for by all the districts(except Shimla, where Pension tops the list). Taking exceptions for Shimla and Lahaul & Spiti, all the districts have same 3 major heads with most expenses made.

# %% [markdown]
# With the exception of Shimla, all the districts have almost similar pattern of expenses for top 10 cateogires of major heads.

# %% [markdown]
# We can conclude that Education, State PF, Medical & Public Health, Social Security, Police, Roads and Bridges are the main areas where most of the money goes.
