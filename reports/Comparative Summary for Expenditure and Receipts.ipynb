# %% [markdown]
# ### Comparative Summary for Expenditure and Receipts

# %%
import comparative_analysis_for_expenditure_and_receipts as comparison_plot

# %% [markdown]
# Below is a comparison of Receipt and Expenditure over a monthly timeline.
#
# It is evident that how much the expenditure varies from Receipt througout the FY.
#
# We can also see that both expenditure and receipts have a spike in April 2018 i.e. first month of the FY.
# For other months, receipts usually decreases while expenditure increases.

# %%
comparison_plot.plot_receipt_exp_timeline()

# %% [markdown]
# Below we compare expenditure and receipts for all districts.
# In general receipts are considerably less than expenditures for all the districts.
#
# Shimla has an unusual gap where receipt is hardly 7 Billions but expenditure is 204 Billions.

# %%
comparison_plot.compare_district_receipt_exp()
