# %% [markdown]
# ### Time Series Expenditure for different districts

# %%
import basic_expenditure_analysis_for_ddo_hoa_soe_vc_bill_wise_data as analysis_plot

# %%
analysis_plot.plot_time_series_for_district_category('BILASPUR', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('CHAMBA', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('HAMIRPUR', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('KANGRA', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('KINNAUR', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('KULLU', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('LAHAUL & SPITI', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('MANDI', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('SHIMLA', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('SIRMAUR', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('SOLAN', 'GROSS')

# %%
analysis_plot.plot_time_series_for_district_category('UNA', 'GROSS')

# %% [markdown]
# We can see that except Lahaul & Spiti(which actually has the lowest expenditure) every district had a spike in expenditure in April 2018 (which is the beginning of the FY 2018-19. Talking about the FY 2017-18, the most expenses occured during Aug-Oct(except some districts which had the spikes in Jan), which seems the time when Revised extimates are also being prepared.
#
# Again, taking exceptions, we can see the lowest expenses occured immediately after the declaration of budget for the FY.
# Lahaul & Spiti seems to be making the exceptions from all other districts when we see general pattern.
