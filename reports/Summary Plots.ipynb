# %% [markdown]
# ###  Some summary plots to see general stats for districts and their expenditures.

# %%
import basic_expenditure_analysis_for_ddo_hoa_soe_vc_bill_wise_data as analysis_plot

# %% [markdown]
# The following plot shows over all expense comparison by districts. Shimla here tops the list with expenses over 200B.

# %%
analysis_plot.plot_district_ranking_for_category('GROSS')

# %% [markdown]
# The following plot shows how much money was spent on different major heads in Himachal Pradesh overall.

# %% [markdown]
# (The graph can be zoomed in for better inspection.)

# %%
analysis_plot.plot_major_head_wise_expenditure('GROSS')

# %% [markdown]
# ### Some highlights:
#
# ##### Top most expenses:
#
#     * General Education is the most prioratized head for expenditure with 78 Billions utilised for it.
#     * Capital outlay on Forestry and Wildlife was the least.
#     * The second highest beneficiary here is Pensions and other Retirement benefits with over 60 Billions.
#     * Little less than 20 Billions are going to Medical & Public Health.
#     * 15 Billions goes to Police.
#     * 14.5 Billions are spent on Roads & Bridges development.
#
# ###### Other important areas of Expenditures:
#
#     * ~8.8 are given for Relief for Natural Calamities.
#     * Animal Husbandry takes nearly 4.5 Billions where Crop Husbandry gets ~6 Billions.
#     * ~4.3 Billions are spent on Family welfare, Urban Development, Foresty and Wildlife gets ~4.5 Billions.
#     * ~3.7 Billions are going for Agricultural Research and Education, Food storage and Warehousing.
#     * Rural Employment is getting ~3 Billions where PWD is geting a littler over 3.6 Billions.
#     * Some 2 Billions are utilised on Labour and Employment.
#     * Nearly 1 Billion is spent on Villages and Small Industries, Arts & Culture, Rural Development Programmes, Nutrition. A little less than 2 Billions on Tourism.
#     * ~780 Millions are spent on Elections.
#
# ###### Some less prioratized ones:
#
#     * Sports and Youth services only gets some ~280 Millions.
#     * Nearly 230 Millions are going to Insurance and Pension funds.
#     * Environment gets nearly 26 Millions.
#     * Flood control and Drainage takes nearly 48 Millions, Water Supply and Sanitation is taking ~8.1 Billions.
#     * Nearly 740 Millions are spent on the wellfare of SC, ST, OBC and other Minorities.
#     * Only ~67 Millions are spent on Renewable Energy.
#     * Census surveys and statistics are taking 140 Millions.

# %%
analysis_plot.plot_pn_expenditure('GROSS')

# %% [markdown]
# Below we compare the different sections of amount spent, specifically how the net payment differs from the gross amount sanctioned.

# %%
analysis_plot.compare_categories_for_districts(['GROSS', 'NETPAYMENT'])

# %% [markdown]
# The following plot shows how the distribution overall looks like for all the districts. We have the Gross amount distributed in three categories: AGDED, BTDED and NETPAYMENT. Here we can see that Shimla has the most utilised Net Payment, though It also has the most money spent.
# Lahaul & Spiti seems to have negligible amount gone in AGDED. There almost all of the gross amount turned out to be the Net Payment.

# %%
analysis_plot.plot_amount_distribution()
