# %%
import basic_expenditure_analysis_for_ddo_hoa_soe_vc_bill_wise_data as analysis_plot

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'BILASPUR')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'CHAMBA')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'HAMIRPUR')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'KANGRA')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'KINNAUR')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'KULLU')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'LAHAUL & SPITI')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'MANDI')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'SHIMLA')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'SIRMAUR')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'SOLAN')

# %%
analysis_plot.plot_pn_expenditure('GROSS', 'UNA')

# %% [markdown]
# Kinnaur, Lahaul & Spiti and Solan seems to have spent some good amount on Plan Expenditures.
