# %% [markdown]
# ### Top 10 Major heads of receipts by districts.

# %%
import basic_receipt_analysis_for_receipt_head_date_and_challan_wise_data as analysis_plot

# %%
analysis_plot.plot_top_10_major_heads_for_district('BILASPUR')

# %%
analysis_plot.plot_top_10_major_heads_for_district('CHAMBA')

# %%
analysis_plot.plot_top_10_major_heads_for_district('HAMIRPUR')

# %%
analysis_plot.plot_top_10_major_heads_for_district('KANGRA')

# %%
analysis_plot.plot_top_10_major_heads_for_district('KINNAUR')

# %%
analysis_plot.plot_top_10_major_heads_for_district('KULLU')

# %%
analysis_plot.plot_top_10_major_heads_for_district('LAHAUL & SPITI')

# %%
analysis_plot.plot_top_10_major_heads_for_district('MANDI')

# %%
analysis_plot.plot_top_10_major_heads_for_district('SHIMLA')

# %%
analysis_plot.plot_top_10_major_heads_for_district('SIRMAUR')

# %%
analysis_plot.plot_top_10_major_heads_for_district('SOLAN')

# %%
analysis_plot.plot_top_10_major_heads_for_district('UNA')

# %% [markdown]
# From the above plots, we can see that the major contributors to different districts' revenue are
# Cash Remittance & Adjustments and State Excise(the most commons), Non-Ferrous Mining and Metallurgical Industries,
# Civil Deposits, Misc Capital Receipts, Tax on sales & trade etc.

# %% [markdown]
# Lahaul & Spiti has the most of its Receipt from Cash remittance and all other are very less in contribution as compared to other districts.
