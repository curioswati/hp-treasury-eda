# %%
import basic_receipt_analysis_for_receipt_head_date_and_challan_wise_data as analysis_plot

# %% [markdown]
# The following plot shows over all receipt comparison by districts. Shimla here tops the list with receipts over 6.5 Billions.

# %%
analysis_plot.plot_district_ranking()

# %% [markdown]
# The following plot shows how much money was received from different major heads in Himachal Pradesh overall.

# %% [markdown]
# (The graph can be zoomed in for better inspection.)

# %%
analysis_plot.plot_major_head_wise_receipt()

# %% [markdown]
# The Following plot shows the composition of Total Receipt amount for districts divided by different group of Major head,
# For example: Tax Revenue, Non Tax Revenue, Debt etc.

# %%
analysis_plot.plot_major_head_groups_district_comparison()

# %% [markdown]
# The following is a timeseries distribution of Net Receipt categorized by Major Heads of Receipt.

# %%
analysis_plot.plot_timeseries_major_head_distribution()

# %%
analysis_plot.plot_top_10_receipt_heads()

# %% [markdown]
# The following is a treemap of groups of different Major heads, such as Tax, Non-Tax, public debt etc.

# %%
analysis_plot.plot_treemap()
