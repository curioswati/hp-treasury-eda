# %% [markdown]
# ### Amount allocated to various Major heads by districts.

# %%
import basic_expenditure_analysis_for_ddo_hoa_soe_vc_bill_wise_data as analysis_plot

# %%
MAJOR_HEADS = [
    'Medical and Public Health',
    'General Education',
    'New and Renewable Energy',
    'Public Works',
    'Elections',
    'Pensions and Other Retirement benefits',
    'Rural Employment',
    'Relief on account of Natural Calamities',
    'Police',
    'Forestry and Wild Life'
]

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'BILASPUR', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'CHAMBA', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'HAMIRPUR', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'KANGRA', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'KINNAUR', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'KULLU', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'LAHAUL & SPITI', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'MANDI', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'SHIMLA', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'SIRMAUR', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'SOLAN', 'GROSS')

# %%
analysis_plot.plot_major_head_wise_expenditure_for_district(MAJOR_HEADS, 'UNA', 'GROSS')

# %% [markdown]
# As we can see that expenses on New & Renewable energy and Rural Employment are almost negligible by all the districts.

# %% [markdown]
# While other districts, despite of having a huge amount spent on one department,
# have considerable amount spent on other important departments
# but Shimla seems to be having a skewness towards Pensions & Retirement benefits with over 45 Billions.
# Only General Education is considered after that, and that too with around 10 Billions only.
