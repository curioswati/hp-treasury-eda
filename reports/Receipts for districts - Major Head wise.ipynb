# %%
import basic_receipt_analysis_for_receipt_head_date_and_challan_wise_data as analysis_plot

# %%
MAJOR_HEADS = [
    'INTEREST RECEIPTS',
    'RECOVERIES TOWARDS PENSION AND OTHER RETIREMENT BENEFITS',
    'DIVIDENDS & PROFITS',
    'TOURISM',
    'STAMPS & REGISTRATION FEES',
    'LAND REVENUE',
    'STATE EXCISE',
    'TAX ON SALES,TRADE ETC.',
    'TAXES ON GOODS & PASSENGERS',
    'OTHER TAXES AND DUTIES ON COMMODITIES AND SERVICES',
    'TAXES ON VEHICLES',
    'TAXES & DUTIES ON ELECTRICITY',
    'GENERAL & OTHER RESERVE FUNDS',
    'INTERNAL DEBT OF STATE GOVERNMENT'
]

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'BILASPUR')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'CHAMBA')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'HAMIRPUR')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'KANGRA')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'KINNAUR')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'KULLU')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'LAHAUL & SPITI')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'MANDI')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'SHIMLA')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'SIRMAUR')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'SOLAN')

# %%
analysis_plot.plot_major_head_wise_receipt_for_district(MAJOR_HEADS, 'UNA')

# %% [markdown]
# From the given list of Major heads, State Excise is the major source of receipt for almost all the districts where Lahaul & Spiti being the only one not having even significant receipt from it.

# %% [markdown]
# Taxes on sales & trade, Taxes on Goods & Passengers, Other Taxes & Duties on Commodities & services and Stamps & Registration fee are most occuring major contributors.

# %% [markdown]
# Internal Debt is almost negligible for all the districts.

# %% [markdown]
# Tourism although isn't contributing much to almost all the districts but seem to be making significant
# for Kullu, Lahaul & Spiti, and Chamba.
